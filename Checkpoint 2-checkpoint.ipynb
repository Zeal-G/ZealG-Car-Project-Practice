# %% [markdown]
# # Checkpoint Two: Exploratory Data Analysis
#
# Now that your chosen dataset is approved, it is time to start working on your analysis. Use this notebook to perform your EDA and make notes where directed to as you work.
#
# ## Getting Started
#
# Since we have not provided your dataset for you, you will need to load the necessary files in this repository. Make sure to include a link back to the original dataset here as well.
#
# My dataset: https://www.kaggle.com/datasets/asinow/car-price-dataset
#
# Your first task in EDA is to import necessary libraries and create a dataframe(s). Make note in the form of code comments of what your thought process is as you work on this setup task.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

#dataframe
Car_DF = pd.read_csv('car_price_dataset.csv')
Car_DF

#first 5 countries most expensive and last 5 least expensive
print(Car_DF.head())
print(Car_DF.tail())
# Out:
#         Brand   Model  Year  Engine_Size Fuel_Type    Transmission  Mileage  \
# 0         Kia     Rio  2020          4.2    Diesel          Manual   289944
# 1   Chevrolet  Malibu  2012          2.0    Hybrid       Automatic     5356
# 2    Mercedes     GLA  2020          4.2    Diesel       Automatic   231440
# 3        Audi      Q5  2023          2.0  Electric          Manual   160971
# 4  Volkswagen    Golf  2003          2.6    Hybrid  Semi-Automatic   286618
#
#    Doors  Owner_Count  Price
# 0      3            5   8501
# 1      2            3  12092
# 2      4            2  11171
# 3      2            1  11780
# 4      3            3   2867
#            Brand     Model  Year  Engine_Size Fuel_Type    Transmission  \
# 9995         Kia    Optima  2004          3.7    Diesel  Semi-Automatic
# 9996   Chevrolet    Impala  2002          1.4  Electric       Automatic
# 9997         BMW  3 Series  2010          3.0    Petrol       Automatic
# 9998        Ford  Explorer  2002          1.4    Hybrid       Automatic
# 9999  Volkswagen    Tiguan  2001          2.1    Diesel          Manual
#
#       Mileage  Doors  Owner_Count  Price
# 9995     5794      2            4   8884
# 9996   168000      2            1   6240
# 9997    86664      5            1   9866
# 9998   225772      4            1   4084
# 9999   157882      3            3   3342

# %% [markdown]
# ## Get to Know the Numbers
#
# Now that you have everything setup, put any code that you use to get to know the dataframe and its rows and columns better in the cell below. You can use whatever techniques you like, except for visualizations. You will put those in a separate section.
#
# When working on your code, make sure to leave comments so that your mentors can understand your thought process.

# %%
#I wanted to see what the data looked like before beginning
#COL_in_countries_df.describe()

top_5_vehicles = Car_DF.head()
print("Top 5 Vehicles")
print(top_5_expensive[['Year', 'Brand', 'Model','Price']])

low_5_vehicles = Car_DF.tail()
print("Low 5 Vehicles")
print(top_5_cheapest[['Year', 'Brand', 'Model','Price' ]])

#mid_index = len(Car_DF) // 2

middle_5_vehicles = Car_DF.iloc[mid_index-2:mid_index+3]
print("5 Average Vehicles")
print(top_5_average[['Year' ,'Brand', 'Model', 'Price']])
# I want the max, min, and middle of the dataset
# Out:
# Top 5 Vehicles
#    Year       Brand   Model  Price
# 0  2020         Kia     Rio   8501
# 1  2012   Chevrolet  Malibu  12092
# 2  2020    Mercedes     GLA  11171
# 3  2023        Audi      Q5  11780
# 4  2003  Volkswagen    Golf   2867
# Low 5 Vehicles
#       Year       Brand     Model  Price
# 9995  2004         Kia    Optima   8884
# 9996  2002   Chevrolet    Impala   6240
# 9997  2010         BMW  3 Series   9866
# 9998  2002        Ford  Explorer   4084
# 9999  2001  Volkswagen    Tiguan   3342
# 5 Average Vehicles
#       Year       Brand     Model  Price
# 4998  2009         BMW  5 Series   4680
# 4999  2012         Kia    Optima   9946
# 5000  2001     Hyundai   Elantra   5308
# 5001  2021       Honda    Accord  11709
# 5002  2016  Volkswagen      Golf  13301

# %% [markdown]
# ## Visualize
#
# Create any visualizations for your EDA here. Make note in the form of code comments of what your thought process is for your visualizations.

# %%
plt.subplot(1, 3, 1)
#Viewing the dataset as scatterplots

sns.scatterplot(data=top_5_vehicles, 
                 x='Year', 
                 y='Price', 
                 color='blue') 
plt.title('Top 5 Vehicles')
plt.xlabel('Car Year')
plt.tight_layout()  
plt.show()

#plt.figure(figsize=(22, 18))
#first bar graph and the base for the following 2 graphs
#plt.subplot(1, 3, 1)
#sns.barplot(data=top_5_expensive, x='Cost of Living Plus Rent Index', y='Country', palette= 'deep6')
#plt.title('Top 5 Most Expensive Countries')
#plt.xlabel('Cost of Living Index')

plt.subplot(1, 3, 2)
sns.scatterplot(data=low_5_vehicles, 
                 x='Year', 
                 y='Price', 
                 color='red') 
plt.title('Low 5 Vehicles')
plt.xlabel('Car Year')
plt.tight_layout()  
plt.show()
#sns.barplot(data=top_5_cheapest, x='Cost of Living Plus Rent Index', y='Country', palette= 'dark6')
#plt.title('Top 5 Cheapest Countries')
#plt.xlabel('Cost of Living Index')

plt.subplot(1,3,3)
sns.scatterplot(data=middle_5_vehicles, 
                 x='Year', 
                 y='Price', 
                 color='green') 
plt.title('Middle 5 Vehicles')
plt.xlabel('Car Year')
plt.tight_layout()  
plt.show()
#sns.barplot(data=top_5_average, x='Cost of Living Plus Rent Index', y='Country', palette= 'colorblind6')
#plt.title('Top 5 Average Countries')
#plt.xlabel('Cost of Living Index')

# %% [markdown]
# ## Summarize Your Results
#
# With your EDA complete, answer the following questions.
#
# 1. Was there anything surprising about your dataset? The middle/average countries number of index wasn't half like I thought it would be from the highest.
# 2. Do you have any concerns about your dataset? Not at the moment, I don't have any concerns about future issues as well.
# 3. Is there anything you want to make note of for the next phase of your analysis, which is cleaning data? I would like to get the number combined with restaurants and cost of living plus rent index.
